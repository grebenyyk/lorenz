# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
rho = 28.0
sigma = 10.0
beta = 8.0 / 3.0

def f(state, t):
    x, y, z = state  # Unpack the state vector
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  # Derivatives

state0 = [1.0, 1.0, 1.0]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)
plt.style.use('dark_background')

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

ax.plot(states[:, 1], states[:, 1], states[:, 2], linewidth=0.5, c = 'white')
ax.grid(False)
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
ax.set_axis_off()

fig.set_size_inches(8,6)
fig.set_dpi(800)
plt.savefig('lorenz.png')
plt.show()

# %%
rho = 28.0
sigma = 10.0
beta = 8.0 / 3.0

def f(state, t):
    x, y, z = state  # Unpack the state vector
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  # Derivatives

state0 = [1.0, 1.0, 1.0]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)
plt.style.use('dark_background')

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

ax.plot(states[:, 0], states[:, 1], states[:, 2], linewidth=0.7, c = '#fc3d03')
ax.grid(False)
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
ax.set_axis_off()

fig.set_size_inches(8,6)
fig.set_dpi(800)
plt.savefig('lorenz.png')
plt.show()
